# %%
import pymortar
import glob
import pandas as pd

URL = "https://beta-api.mortardata.org"
# connect client to Mortar frontend server
c = pymortar.Client(URL)

# %%
# !pip show pymortar
# Out:
# Name: pymortar
# Version: 2.0.4
# Summary:
# Home-page: None
# Author: Gabe Fierro
# Author-email: gtfierro@cs.berkeley.edu
# License: None
# Location: /opt/anaconda3/lib/python3.8/site-packages
# Requires: brickschema, rdflib, googleapis-common-protos, requests, pandas, pyarrow, zstd, python-snappy
# Required-by:

# %%
# query AHU, supply air temp sensor, and downstream zone
query_ahu = """SELECT ?ahu ?sat ?zone WHERE {
    # ?ahu a brick:AHU .
    # ?ahu brick:hasPart?/brick:hasPoint ?sat .
    # ?sat a brick:Supply_Air_Temperature_Sensor .
    # ?ahu brick:feeds+ ?zone .
    # ?zone a brick:HVAC_Zone
}"""

# all air temperature sensors
query_temp_sensor = """SELECT ?ats WHERE {
    # ?ats  a  brick:Air_Temperature_Sensor .
}"""

# %%
# query setpoints on thermostats and zones that they are located in
query_setpoints = """SELECT ?stp ?zone ?HVACzone WHERE {
    # ?stp a brick:Zone_Air_Temperature_Setpoint .
    # ?HVACzone a brick:HVAC_Zone .
    # ?HVACzone brick:hasPoint ?stp
}"""

# can I write zone a brick: ?zone, cause it is not a brick entity but a tag

# query air temperature and zones that they are located in
query_atemp = """SELECT ?atemp ?zone ?HVACzone WHERE {
    # ?atemp a brick:Zone_Air_Temperature_Sensor .
    # ?HVACzone a brick:HVAC_Zone
    # ?HVACzone brick:hasPoint ?atemp
}"""

# %% [markdown]
# ## Querying (Brick) Metadata

# %%
# display all content in a column
pd.set_option('display.max_colwidth', -1)
# Out:
# <ipython-input-5-e95239d8dc4e>:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
# get all qualifed buildind sites for a list of queries
c.qualify([query_ahu, query_temp_sensor])

# name the queries (optional)
# c.qualify({"damper_cmd": query2, "ahu sat": query1, "temp sensors": query3})
# Out:
# 2021-08-03:11:01:57,132 ERROR   [__init__.py:319] Error getting metadata b'<html>\r\n<head><title>502 Bad Gateway</title></head>\r\n<body bgcolor="white">\r\n<center><h1>502 Bad Gateway</h1></center>\r\n<hr><center>nginx/1.14.0 (Ubuntu)</center>\r\n</body>\r\n</html>\r\n'
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-6-8cef151801ca> in <module>
#       1 # get all qualifed buildind sites for a list of queries
# ----> 2 c.qualify([query_ahu, query_temp_sensor])
#       3
#       4 # name the queries (optional)
#       5 # c.qualify({"damper_cmd": query2, "ahu sat": query1, "temp sensors": query3})
#
# /opt/anaconda3/lib/python3.8/site-packages/pymortar/__init__.py in qualify(self, required_queries)
#     318         if not res.ok:
#     319             logging.error("Error getting metadata %s" % res.content)
# --> 320             raise Exception(res.content)
#     321         return QualifyResult(res.json(), names=names)
#     322
#
# Exception: b'<html>\r\n<head><title>502 Bad Gateway</title></head>\r\n<body bgcolor="white">\r\n<center><h1>502 Bad Gateway</h1></center>\r\n<hr><center>nginx/1.14.0 (Ubuntu)</center>\r\n</body>\r\n</html>\r\n'

# %%
c.qualify([query_setpoints])

# %%
# execute query against all sites
# I never successfully run this due to extreme long runtime
# client.sparql(query_ahu)

# execute query against a list of sites
c.sparql(query_ahu, sites=['scc'])
# Out:
#                                          ahu  \
# 0   http://buildsys.org/ontologies/SCC#AHU01
# 1   http://buildsys.org/ontologies/SCC#AHU01
# 2   http://buildsys.org/ontologies/SCC#AHU01
# 3   http://buildsys.org/ontologies/SCC#AHU01
# 4   http://buildsys.org/ontologies/SCC#AHU01
# 5   http://buildsys.org/ontologies/SCC#AHU01
# 6   http://buildsys.org/ontologies/SCC#AHU01
# 7   http://buildsys.org/ontologies/SCC#AHU01
# 8   http://buildsys.org/ontologies/SCC#AHU01
# 9   http://buildsys.org/ontologies/SCC#AHU01
# 10  http://buildsys.org/ontologies/SCC#AHU01
# 11  http://buildsys.org/ontologies/SCC#AHU01
# 12  http://buildsys.org/ontologies/SCC#AHU01
# 13  http://buildsys.org/ontologies/SCC#AHU01
# 14  http://buildsys.org/ontologies/SCC#AHU01
# 15  http://buildsys.org/ontologies/SCC#AHU01
# 16  http://buildsys.org/ontologies/SCC#AHU01
# 17  http://buildsys.org/ontologies/SCC#AHU01
# 18  http://buildsys.org/ontologies/SCC#AHU01
# 19  http://buildsys.org/ontologies/SCC#AHU01
# 20  http://buildsys.org/ontologies/SCC#AHU01
# 21  http://buildsys.org/ontologies/SCC#AHU01
# 22  http://buildsys.org/ontologies/SCC#AHU01
# 23  http://buildsys.org/ontologies/SCC#AHU01
# 24  http://buildsys.org/ontologies/SCC#AHU01
# 25  http://buildsys.org/ontologies/SCC#AHU01
# 26  http://buildsys.org/ontologies/SCC#AHU01
# 27  http://buildsys.org/ontologies/SCC#AHU01
# 28  http://buildsys.org/ontologies/SCC#AHU01
# 29  http://buildsys.org/ontologies/SCC#AHU01
# 30  http://buildsys.org/ontologies/SCC#AHU01
# 31  http://buildsys.org/ontologies/SCC#AHU01
# 32  http://buildsys.org/ontologies/SCC#AHU01
# 33  http://buildsys.org/ontologies/SCC#AHU01
# 34  http://buildsys.org/ontologies/SCC#AHU01
# 35  http://buildsys.org/ontologies/SCC#AHU01
# 36  http://buildsys.org/ontologies/SCC#AHU01
# 37  http://buildsys.org/ontologies/SCC#AHU01
# 38  http://buildsys.org/ontologies/SCC#AHU01
# 39  http://buildsys.org/ontologies/SCC#AHU01
# 40  http://buildsys.org/ontologies/SCC#AHU01
# 41  http://buildsys.org/ontologies/SCC#AHU01
# 42  http://buildsys.org/ontologies/SCC#AHU01
# 43  http://buildsys.org/ontologies/SCC#AHU01
# 44  http://buildsys.org/ontologies/SCC#AHU01
#
#                                                                  sat  \
# 0   http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 1   http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 2   http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 3   http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 4   http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 5   http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 6   http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 7   http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 8   http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 9   http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 10  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 11  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 12  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 13  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 14  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 15  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 16  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 17  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 18  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 19  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 20  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 21  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 22  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 23  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 24  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 25  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 26  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 27  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 28  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 29  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 30  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 31  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 32  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 33  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 34  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 35  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 36  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 37  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 38  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 39  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 40  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 41  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 42  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 43  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 44  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
#
#                                            zone site
# 0   http://buildsys.org/ontologies/SCC#RM1415    scc
# 1   http://buildsys.org/ontologies/SCC#RM1101A   scc
# 2   http://buildsys.org/ontologies/SCC#RM1003    scc
# 3   http://buildsys.org/ontologies/SCC#RM1309    scc
# 4   http://buildsys.org/ontologies/SCC#RM2102    scc
# 5   http://buildsys.org/ontologies/SCC#RM2405    scc
# 6   http://buildsys.org/ontologies/SCC#RM1310    scc
# 7   http://buildsys.org/ontologies/SCC#RM1303    scc
# 8   http://buildsys.org/ontologies/SCC#RM1001    scc
# 9   http://buildsys.org/ontologies/SCC#RM2410    scc
# 10  http://buildsys.org/ontologies/SCC#RM1410    scc
# 11  http://buildsys.org/ontologies/SCC#RM1306    scc
# 12  http://buildsys.org/ontologies/SCC#RM2401    scc
# 13  http://buildsys.org/ontologies/SCC#RM2002    scc
# 14  http://buildsys.org/ontologies/SCC#RM1402A   scc
# 15  http://buildsys.org/ontologies/SCC#RM2203    scc
# 16  http://buildsys.org/ontologies/SCC#RM1413    scc
# 17  http://buildsys.org/ontologies/SCC#RM2101_2  scc
# 18  http://buildsys.org/ontologies/SCC#RM2407    scc
# 19  http://buildsys.org/ontologies/SCC#RM2103    scc
# 20  http://buildsys.org/ontologies/SCC#RM2303    scc
# 21  http://buildsys.org/ontologies/SCC#RM2004    scc
# 22  http://buildsys.org/ontologies/SCC#RM1200    scc
# 23  http://buildsys.org/ontologies/SCC#RM1304    scc
# 24  http://buildsys.org/ontologies/SCC#RM1105    scc
# 25  http://buildsys.org/ontologies/SCC#RM2101_1  scc
# 26  http://buildsys.org/ontologies/SCC#RM1200A   scc
# 27  http://buildsys.org/ontologies/SCC#RM1405    scc
# 28  http://buildsys.org/ontologies/SCC#RM2201    scc
# 29  http://buildsys.org/ontologies/SCC#RM2001    scc
# 30  http://buildsys.org/ontologies/SCC#RM2310    scc
# 31  http://buildsys.org/ontologies/SCC#RM2312    scc
# 32  http://buildsys.org/ontologies/SCC#RM2001A   scc
# 33  http://buildsys.org/ontologies/SCC#RM2003    scc
# 34  http://buildsys.org/ontologies/SCC#RM2204    scc
# 35  http://buildsys.org/ontologies/SCC#RM1110    scc
# 36  http://buildsys.org/ontologies/SCC#RM1402    scc
# 37  http://buildsys.org/ontologies/SCC#RM1002    scc
# 38  http://buildsys.org/ontologies/SCC#RM1101_2  scc
# 39  http://buildsys.org/ontologies/SCC#RM1301    scc
# 40  http://buildsys.org/ontologies/SCC#RM2311    scc
# 41  http://buildsys.org/ontologies/SCC#RM2301    scc
# 42  http://buildsys.org/ontologies/SCC#RM1417    scc
# 43  http://buildsys.org/ontologies/SCC#RM2101A   scc
# 44  http://buildsys.org/ontologies/SCC#RM1201    scc

# %% [markdown]
# ## Querying Timeseries data

# %%
# get SPARQL query results, stream metadata data tables as separate objects

# query data from all sites
# res = c.data_sparql(query_ahu)

# query data from specific URLs
res = c.data_uris(["http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp"])

# %%
res.data
# Out:
#                             time  value  \
# 0      2013-05-15 23:45:00+00:00  65.3
# 1      2013-05-15 23:30:00+00:00  63.5
# 2      2013-05-15 23:15:00+00:00  62.8
# 3      2013-05-15 23:00:00+00:00  62.4
# 4      2013-05-15 22:45:00+00:00  61.2
# ...                          ...   ...
# 184596 2017-11-30 01:00:00+00:00  67.1
# 184597 2017-11-30 00:45:00+00:00  68.1
# 184598 2017-11-30 00:30:00+00:00  69.5
# 184599 2017-11-30 00:15:00+00:00  69.0
# 184600 2017-11-30 00:00:00+00:00  68.5
#
#                                                                       id
# 0       http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 1       http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 2       http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 3       http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 4       http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# ...                                                                  ...
# 184596  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 184597  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 184598  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 184599  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
# 184600  http://buildsys.org/ontologies/SCC#SCC.AHU.AHU01.Supply_Air_Temp
#
# [184601 rows x 3 columns]
